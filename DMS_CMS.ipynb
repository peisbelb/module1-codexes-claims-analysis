# %% [markdown]
# <a href="https://colab.research.google.com/github/peisbelb/module1-codexes-claims-analysis/blob/main/DMS_CMS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !pip install pandas

# %%
df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/647931dd-f8ea-423a-98a3-655e586a7c1f/dme.csv')

# %%
df
# Out:
#        BENE_ID|CLM_ID|NCH_NEAR_LINE_REC_IDENT_CD|NCH_CLM_TYPE_CD|CLM_FROM_DT|CLM_THRU_DT|NCH_WKLY_PROC_DT|CARR_CLM_ENTRY_CD|CLM_DISP_CD|CARR_NUM|CARR_CLM_PMT_DNL_CD|CLM_PMT_AMT|CARR_CLM_PRMRY_PYR_PD_AMT|CARR_CLM_PRVDR_ASGNMT_IND_SW|NCH_CLM_PRVDR_PMT_AMT|NCH_CLM_BENE_PMT_AMT|NCH_CARR_CLM_SBMTD_CHRG_AMT|NCH_CARR_CLM_ALOWD_AMT|CARR_CLM_CASH_DDCTBL_APLD_AMT|CARR_CLM_HCPCS_YR_CD|PRNCPAL_DGNS_CD|PRNCPAL_DGNS_VRSN_CD|ICD_DGNS_CD1|ICD_DGNS_VRSN_CD1|ICD_DGNS_CD2|ICD_DGNS_VRSN_CD2|ICD_DGNS_CD3|ICD_DGNS_VRSN_CD3|ICD_DGNS_CD4|ICD_DGNS_VRSN_CD4|ICD_DGNS_CD5|ICD_DGNS_VRSN_CD5|ICD_DGNS_CD6|ICD_DGNS_VRSN_CD6|ICD_DGNS_CD7|ICD_DGNS_VRSN_CD7|ICD_DGNS_CD8|ICD_DGNS_VRSN_CD8|ICD_DGNS_CD9|ICD_DGNS_VRSN_CD9|ICD_DGNS_CD10|ICD_DGNS_VRSN_CD10|ICD_DGNS_CD11|ICD_DGNS_VRSN_CD11|ICD_DGNS_CD12|ICD_DGNS_VRSN_CD12|RFR_PHYSN_UPIN|RFR_PHYSN_NPI|CLM_CLNCL_TRIL_NUM|LINE_NUM|TAX_NUM|PRVDR_SPCLTY|PRTCPTNG_IND_CD|LINE_SRVC_CNT|LINE_CMS_TYPE_SRVC_CD|LINE_PLACE_OF_SRVC_CD|LINE_1ST_EXPNS_DT|LINE_LAST_EXPNS_DT|HCPCS_CD|HCPCS_1S
# ...

# %%
df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/647931dd-f8ea-423a-98a3-655e586a7c1f/dme.csv', sep = '|')

# %%
df
# Out:
#                BENE_ID          CLM_ID NCH_NEAR_LINE_REC_IDENT_CD  \
# 0      -10000010254618 -10000930037927                          M
# 1      -10000010254618 -10000930037958                          M
# 2      -10000010254618 -10000930037981                          M
# 3      -10000010254618 -10000930037986                          M
# 4      -10000010254618 -10000930037994                          M
# ...                ...             ...                        ...
# 103823 -10000010288010 -10000931486121                          M
# 103824 -10000010288010 -10000931486126                          M
# 103825 -10000010288010 -10000931486126                          M
# 103826 -10000010288010 -10000931486134                          M
# 103827 -10000010288010 -10000931486137                          M
#
#         NCH_CLM_TYPE_CD  CLM_FROM_DT  CLM_THRU_DT NCH_WKLY_PROC_DT  \
# 0                    82  25-Mar-2015  25-Mar-2015      24-Apr-2015
# ...

# %%
df.sample(25)
# Out:
#               BENE_ID          CLM_ID NCH_NEAR_LINE_REC_IDENT_CD  \
# 68870 -10000010275400 -10000930972020                          M
# 52134 -10000010270365 -10000930728331                          M
# 63882 -10000010273940 -10000930898927                          M
# 52470 -10000010270630 -10000930738063                          M
# 27794 -10000010262704 -10000930403026                          M
# 65502 -10000010274668 -10000930936865                          M
# 40591 -10000010266874 -10000930581114                          M
# 25601 -10000010262379 -10000930384253                          M
# 65075 -10000010274404 -10000930918838                          M
# 26363 -10000010262514 -10000930389477                          M
# 85173 -10000010280804 -10000931198875                          M
# 78290 -10000010278053 -10000931102269                          M
# 87267 -10000010281743 -10000931232172                          M
# ...

# %%
### now lets look at column name
df.columns ##variable name we gave to the data set
# Out:
# Index(['BENE_ID', 'CLM_ID', 'NCH_NEAR_LINE_REC_IDENT_CD', 'NCH_CLM_TYPE_CD',
#        'CLM_FROM_DT', 'CLM_THRU_DT', 'NCH_WKLY_PROC_DT', 'CARR_CLM_ENTRY_CD',
#        'CLM_DISP_CD', 'CARR_NUM', 'CARR_CLM_PMT_DNL_CD', 'CLM_PMT_AMT',
#        'CARR_CLM_PRMRY_PYR_PD_AMT', 'CARR_CLM_PRVDR_ASGNMT_IND_SW',
#        'NCH_CLM_PRVDR_PMT_AMT', 'NCH_CLM_BENE_PMT_AMT',
#        'NCH_CARR_CLM_SBMTD_CHRG_AMT', 'NCH_CARR_CLM_ALOWD_AMT',
#        'CARR_CLM_CASH_DDCTBL_APLD_AMT', 'CARR_CLM_HCPCS_YR_CD',
#        'PRNCPAL_DGNS_CD', 'PRNCPAL_DGNS_VRSN_CD', 'ICD_DGNS_CD1',
#        'ICD_DGNS_VRSN_CD1', 'ICD_DGNS_CD2', 'ICD_DGNS_VRSN_CD2',
#        'ICD_DGNS_CD3', 'ICD_DGNS_VRSN_CD3', 'ICD_DGNS_CD4',
#        'ICD_DGNS_VRSN_CD4', 'ICD_DGNS_CD5', 'ICD_DGNS_VRSN_CD5',
#        'ICD_DGNS_CD6', 'ICD_DGNS_VRSN_CD6', 'ICD_DGNS_CD7',
#        'ICD_DGNS_VRSN_CD7', 'ICD_DGNS_CD8', 'ICD_DGNS_VRSN_CD8',
#        'ICD_DGNS_CD9', 'ICD_DGNS_VRSN_CD9', 'ICD_DGNS_CD10',
# ...

# %%
for column in df.columns:
    print(column) ####change the name, it could be x, column, just a place holder.
# Out:
# BENE_ID
# CLM_ID
# NCH_NEAR_LINE_REC_IDENT_CD
# NCH_CLM_TYPE_CD
# CLM_FROM_DT
# CLM_THRU_DT
# NCH_WKLY_PROC_DT
# CARR_CLM_ENTRY_CD
# CLM_DISP_CD
# CARR_NUM
# CARR_CLM_PMT_DNL_CD
# CLM_PMT_AMT
# CARR_CLM_PRMRY_PYR_PD_AMT
# CARR_CLM_PRVDR_ASGNMT_IND_SW
# NCH_CLM_PRVDR_PMT_AMT
# NCH_CLM_BENE_PMT_AMT
# NCH_CARR_CLM_SBMTD_CHRG_AMT
# NCH_CARR_CLM_ALOWD_AMT
# CARR_CLM_CASH_DDCTBL_APLD_AMT
# CARR_CLM_HCPCS_YR_CD
# PRNCPAL_DGNS_CD
# PRNCPAL_DGNS_VRSN_CD
# ICD_DGNS_CD1
# ICD_DGNS_VRSN_CD1
# ICD_DGNS_CD2
# ICD_DGNS_VRSN_CD2
# ICD_DGNS_CD3
# ICD_DGNS_VRSN_CD3
# ICD_DGNS_CD4
# ICD_DGNS_VRSN_CD4
# ICD_DGNS_CD5
# ICD_DGNS_VRSN_CD5
# ICD_DGNS_CD6
# ICD_DGNS_VRSN_CD6
# ICD_DGNS_CD7
# ICD_DGNS_VRSN_CD7
# ICD_DGNS_CD8
# ICD_DGNS_VRSN_CD8
# ICD_DGNS_CD9
# ICD_DGNS_VRSN_CD9
# ICD_DGNS_CD10
# ICD_DGNS_VRSN_CD10
# ICD_DGNS_CD11
# ICD_DGNS_VRSN_CD11
# ICD_DGNS_CD12
# ICD_DGNS_VRSN_CD12
# RFR_PHYSN_UPIN
# RFR_PHYSN_NPI
# CLM_CLNCL_TRIL_NUM
# LINE_NUM
# TAX_NUM
# PRVDR_SPCLTY
# PRTCPTNG_IND_CD
# ...

# %%
# df.PRNCPAL_DGNS_CD
# df['PRNCPAL_DGNS_CD']

# %%
df['PRNCPAL_DGNS_CD']
# Out:
# 0         S134XX
# 1          Z9189
# 2           Z591
# 3         T7432X
# 4         T7422X
#            ...
# 103823      Z608
# 103824      Z608
# 103825      Z608
# 103826      Z608
# 103827      Z733
# Name: PRNCPAL_DGNS_CD, Length: 103828, dtype: object

# %%
#### get unique count of CLM_ID
count = df.CLM_ID.unique()
len(count) #unique names! This is not the unit of analysis or least common denominator?? important to understand what each row means
# Out:
# 37782

# %%
df['PRNCPAL_DGNS_CD']. value_counts() ##most frequent/least frequent ICD 10 codes
# Out:
# PRNCPAL_DGNS_CD
# Z733       33868
# Z608       19905
# T7432X      9038
# Z604        8334
# G479        1527
#            ...
# E113599        1
# Z7689          1
# Z558           1
# Z9189          1
# N390           1
# Name: count, Length: 212, dtype: int64

# %%
icd_primary_counts = df['PRNCPAL_DGNS_CD']. value_counts()

# %%
icd_primary_counts
# Out:
# PRNCPAL_DGNS_CD
# Z733       33868
# Z608       19905
# T7432X      9038
# Z604        8334
# G479        1527
#            ...
# E113599        1
# Z7689          1
# Z558           1
# Z9189          1
# N390           1
# Name: count, Length: 212, dtype: int64

# %%
type(icd_primary_counts)
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes ##dtypes tells us whether each column is an integer or a number, not ALWAYS accurate tho so be careful.
# Out:
# BENE_ID                         int64
# CLM_ID                          int64
# NCH_NEAR_LINE_REC_IDENT_CD     object
# NCH_CLM_TYPE_CD                 int64
# CLM_FROM_DT                    object
#                                ...
# DMERC_LINE_SCRN_SVGS_AMT        int64
# DMERC_LINE_MTUS_CNT           float64
# DMERC_LINE_MTUS_CD              int64
# LINE_HCT_HGB_RSLT_NUM         float64
# LINE_NDC_CD                   float64
# Length: 87, dtype: object

# %%
df['CLM_PMT_AMT'].describe()
# Out:
# count    103828.000000
# mean          5.519663
# std          13.418350
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           6.560000
# max         128.500000
# Name: CLM_PMT_AMT, dtype: float64

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of                BENE_ID          CLM_ID NCH_NEAR_LINE_REC_IDENT_CD  \
# 0      -10000010254618 -10000930037927                          M
# 1      -10000010254618 -10000930037958                          M
# 2      -10000010254618 -10000930037981                          M
# 3      -10000010254618 -10000930037986                          M
# 4      -10000010254618 -10000930037994                          M
# ...                ...             ...                        ...
# 103823 -10000010288010 -10000931486121                          M
# 103824 -10000010288010 -10000931486126                          M
# 103825 -10000010288010 -10000931486126                          M
# 103826 -10000010288010 -10000931486134                          M
# 103827 -10000010288010 -10000931486137                          M
#
#         NCH_CLM_TYPE_CD  CLM_FROM_DT  CLM_THRU_DT NCH_WKLY_PROC_DT  \
# 0                    82  25-Mar-2015  25-Mar-2015      24-Apr-2015
# ...

# %%
codex_columns = [
    'PRNCPAL_DGNS_CD',
    'ICD_DGNS_CD1',
    'ICD_PRCDR_CD1',
    'CLM_DRG_CD',
    'ADMTG_DGNS_CD',
    'HCPCS_CD',
    'FST_DGNS_E_CD',
    'NCH_DRG_OUTLIER_APRVD_PMT_AMT'
]
for column in codex_columns:
    print(f"Frequency counts for {column}:")
    value_counts = df[column].value_counts()
    print(df[column].value_counts())
    print("\n")
# Out:
# Frequency counts for PRNCPAL_DGNS_CD:
# PRNCPAL_DGNS_CD
# Z733       33868
# Z608       19905
# T7432X      9038
# Z604        8334
# G479        1527
#            ...
# E113599        1
# Z7689          1
# Z558           1
# Z9189          1
# N390           1
# Name: count, Length: 212, dtype: int64
#
#
# Frequency counts for ICD_DGNS_CD1:
# ICD_DGNS_CD1
# Z733       34103
# Z608       20036
# T7432X      9098
# Z604        8390
# Z653        1197
#            ...
# E113599        1
# Z558           1
# B9561          1
# Z9189          1
# O1410          1
# Name: count, Length: 214, dtype: int64
#
#
# Frequency counts for ICD_PRCDR_CD1:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
# ...

# %%
codex_columns = [
    'PRNCPAL_DGNS_CD',
    'ICD_DGNS_CD1',
    'HCPCS_CD'
]
for column in codex_columns:
    print(f"Frequency counts for {column}:")
    value_counts = df[column].value_counts()
    print(df[column].value_counts())
    print("\n")
# Out:
# Frequency counts for PRNCPAL_DGNS_CD:
# PRNCPAL_DGNS_CD
# Z733       33868
# Z608       19905
# T7432X      9038
# Z604        8334
# G479        1527
#            ...
# E113599        1
# Z7689          1
# Z558           1
# Z9189          1
# N390           1
# Name: count, Length: 212, dtype: int64
#
#
# Frequency counts for ICD_DGNS_CD1:
# ICD_DGNS_CD1
# Z733       34103
# Z608       20036
# T7432X      9098
# Z604        8390
# Z653        1197
#            ...
# E113599        1
# Z558           1
# B9561          1
# Z9189          1
# O1410          1
# Name: count, Length: 214, dtype: int64
#
#
# Frequency counts for HCPCS_CD:
# HCPCS_CD
# A4253    18882
# A7038    16295
# A7035    16295
# A7037     8148
# A4604     8147
# A7034     8137
# A4259     7018
# A7031     4136
# A7030     4022
# E0601     3371
# A7046     1705
# E0562     1666
# K0001      972
# A4256      754
# E0485      718
# E0570      450
# E1390      383
# E0260      362
# E0607      317
# E1038      277
# ...
