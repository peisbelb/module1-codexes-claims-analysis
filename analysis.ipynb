# %% [markdown]
# <a href="https://colab.research.google.com/github/peisbelb/module1-codexes-claims-analysis/blob/main/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !pip install pandas

# %%
df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/67157de9-d962-4af0-bf0e-3578b3afec58/inpatient.csv')

# %%
df
# Out:
#       BENE_ID|CLM_ID|NCH_NEAR_LINE_REC_IDENT_CD|NCH_CLM_TYPE_CD|CLM_FROM_DT|CLM_THRU_DT|NCH_WKLY_PROC_DT|FI_CLM_PROC_DT|CLAIM_QUERY_CODE|PRVDR_NUM|CLM_FAC_TYPE_CD|CLM_SRVC_CLSFCTN_TYPE_CD|CLM_FREQ_CD|FI_NUM|CLM_MDCR_NON_PMT_RSN_CD|CLM_PMT_AMT|NCH_PRMRY_PYR_CLM_PD_AMT|NCH_PRMRY_PYR_CD|FI_CLM_ACTN_CD|PRVDR_STATE_CD|ORG_NPI_NUM|AT_PHYSN_UPIN|AT_PHYSN_NPI|OP_PHYSN_UPIN|OP_PHYSN_NPI|OT_PHYSN_UPIN|OT_PHYSN_NPI|CLM_MCO_PD_SW|PTNT_DSCHRG_STUS_CD|CLM_PPS_IND_CD|CLM_TOT_CHRG_AMT|CLM_ADMSN_DT|CLM_IP_ADMSN_TYPE_CD|CLM_SRC_IP_ADMSN_CD|NCH_PTNT_STATUS_IND_CD|CLM_PASS_THRU_PER_DIEM_AMT|NCH_BENE_IP_DDCTBL_AMT|NCH_BENE_PTA_COINSRNC_LBLTY_AM|NCH_BENE_BLOOD_DDCTBL_LBLTY_AM|NCH_PROFNL_CMPNT_CHRG_AMT|NCH_IP_NCVRD_CHRG_AMT|NCH_IP_TOT_DDCTN_AMT|CLM_TOT_PPS_CPTL_AMT|CLM_PPS_CPTL_FSP_AMT|CLM_PPS_CPTL_OUTLIER_AMT|CLM_PPS_CPTL_DSPRPRTNT_SHR_AMT|CLM_PPS_CPTL_IME_AMT|CLM_PPS_CPTL_EXCPTN_AMT|CLM_PPS_OLD_CPTL_HLD_HRMLS_AMT|CLM_PPS_CPTL_DRG_WT_NUM|CLM_UTLZTN_DAY_CNT|BENE_TOT_COINSRNC_DAYS_CNT|BENE_LRD_USED_CNT|CLM_
# ...

# %%
df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/67157de9-d962-4af0-bf0e-3578b3afec58/inpatient.csv', sep = '|')
# Out:
# <ipython-input-8-d205db3038f8>:1: DtypeWarning: Columns (168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/67157de9-d962-4af0-bf0e-3578b3afec58/inpatient.csv', sep = '|')

# %%
df
# Out:
#               BENE_ID          CLM_ID NCH_NEAR_LINE_REC_IDENT_CD  \
# 0     -10000010254618 -10000930037831                          V
# 1     -10000010254653 -10000930038030                          V
# 2     -10000010254653 -10000930038031                          V
# 3     -10000010254656 -10000930038162                          V
# 4     -10000010254656 -10000930038162                          V
# ...               ...             ...                        ...
# 58061 -10000010288008 -10000931485965                          V
# 58062 -10000010288008 -10000931485967                          V
# 58063 -10000010288008 -10000931485969                          V
# 58064 -10000010288008 -10000931485971                          V
# 58065 -10000010288010 -10000931486024                          V
#
#        NCH_CLM_TYPE_CD  CLM_FROM_DT  CLM_THRU_DT NCH_WKLY_PROC_DT  \
# 0                   60  25-Mar-2015  25-Mar-2015      27-Mar-2015
# ...

# %%
df.sample(25)
# Out:
#               BENE_ID          CLM_ID NCH_NEAR_LINE_REC_IDENT_CD  \
# 26405 -10000010262514 -10000930389510                          M
# 93873 -10000010283962 -10000931330163                          M
# 39428 -10000010266311 -10000930554017                          M
# 24434 -10000010262067 -10000930367536                          M
# 182   -10000010254730 -10000930040092                          M
# 31386 -10000010263769 -10000930450593                          M
# 81027 -10000010279058 -10000931139428                          M
# 68754 -10000010275400 -10000930971984                          M
# 46075 -10000010268427 -10000930648916                          M
# 69564 -10000010275429 -10000930973506                          M
# 45186 -10000010268083 -10000930632462                          M
# 13437 -10000010258625 -10000930218627                          M
# 16621 -10000010259388 -10000930251326                          M
# ...

# %%
### now lets look at column name
df.columns ##variable name we gave to the data set
# Out:
# Index(['BENE_ID', 'CLM_ID', 'NCH_NEAR_LINE_REC_IDENT_CD', 'NCH_CLM_TYPE_CD',
#        'CLM_FROM_DT', 'CLM_THRU_DT', 'NCH_WKLY_PROC_DT', 'FI_CLM_PROC_DT',
#        'CLAIM_QUERY_CODE', 'PRVDR_NUM',
#        ...
#        'PRCDR_DT24', 'ICD_PRCDR_CD25', 'PRCDR_DT25', 'IME_OP_CLM_VAL_AMT',
#        'DSH_OP_CLM_VAL_AMT', 'CLM_UNCOMPD_CARE_PMT_AMT', 'CLM_LINE_NUM',
#        'REV_CNTR', 'HCPCS_CD', 'REV_CNTR_DDCTBL_COINSRNC_CD'],
#       dtype='object', length=197)

# %%
for column in df.columns:
    print(column) ####change the name, it could be x, column, just a place holder.
# Out:
# BENE_ID
# CLM_ID
# NCH_NEAR_LINE_REC_IDENT_CD
# NCH_CLM_TYPE_CD
# CLM_FROM_DT
# CLM_THRU_DT
# NCH_WKLY_PROC_DT
# FI_CLM_PROC_DT
# CLAIM_QUERY_CODE
# PRVDR_NUM
# CLM_FAC_TYPE_CD
# CLM_SRVC_CLSFCTN_TYPE_CD
# CLM_FREQ_CD
# FI_NUM
# CLM_MDCR_NON_PMT_RSN_CD
# CLM_PMT_AMT
# NCH_PRMRY_PYR_CLM_PD_AMT
# NCH_PRMRY_PYR_CD
# FI_CLM_ACTN_CD
# PRVDR_STATE_CD
# ORG_NPI_NUM
# AT_PHYSN_UPIN
# AT_PHYSN_NPI
# OP_PHYSN_UPIN
# OP_PHYSN_NPI
# OT_PHYSN_UPIN
# OT_PHYSN_NPI
# CLM_MCO_PD_SW
# PTNT_DSCHRG_STUS_CD
# CLM_PPS_IND_CD
# CLM_TOT_CHRG_AMT
# CLM_ADMSN_DT
# CLM_IP_ADMSN_TYPE_CD
# CLM_SRC_IP_ADMSN_CD
# NCH_PTNT_STATUS_IND_CD
# CLM_PASS_THRU_PER_DIEM_AMT
# NCH_BENE_IP_DDCTBL_AMT
# NCH_BENE_PTA_COINSRNC_LBLTY_AM
# NCH_BENE_BLOOD_DDCTBL_LBLTY_AM
# NCH_PROFNL_CMPNT_CHRG_AMT
# NCH_IP_NCVRD_CHRG_AMT
# NCH_IP_TOT_DDCTN_AMT
# CLM_TOT_PPS_CPTL_AMT
# CLM_PPS_CPTL_FSP_AMT
# CLM_PPS_CPTL_OUTLIER_AMT
# CLM_PPS_CPTL_DSPRPRTNT_SHR_AMT
# CLM_PPS_CPTL_IME_AMT
# CLM_PPS_CPTL_EXCPTN_AMT
# CLM_PPS_OLD_CPTL_HLD_HRMLS_AMT
# ...

# %%
# df.PRNCPAL_DGNS_CD
# df['PRNCPAL_DGNS_CD']

# %%
df['PRNCPAL_DGNS_CD']
# Out:
# 0         S134XX
# 1          Z3480
# 2         T7432X
# 3         S8290X
# 4         S8290X
#           ...
# 58061    T50901A
# 58062    T50901A
# 58063    T50901A
# 58064    T50901A
# 58065     S93409
# Name: PRNCPAL_DGNS_CD, Length: 58066, dtype: object

# %%
#### get unique count of CLM_ID
count = df.CLM_ID.unique()
len(count) #unique names! This is not the unit of analysis or least common denominator?? important to understand what each row means
# Out:
# 20867

# %%
df['PRNCPAL_DGNS_CD']. value_counts() ##most frequent/least frequent ICD 10 codes
# Out:
# PRNCPAL_DGNS_CD
# Z733      11469
# Z608       7216
# T7432X     3314
# Z604       3227
# Z7682      3092
#           ...
# I25700        1
# I200          1
# E849          1
# A4152         1
# O00109        1
# Name: count, Length: 190, dtype: int64

# %%
icd_primary_counts = df['PRNCPAL_DGNS_CD']. value_counts()

# %%
icd_primary_counts
# Out:
# PRNCPAL_DGNS_CD
# Z733      11469
# Z608       7216
# T7432X     3314
# Z604       3227
# Z7682      3092
#           ...
# I25700        1
# I200          1
# E849          1
# A4152         1
# O00109        1
# Name: count, Length: 190, dtype: int64

# %%
type(icd_primary_counts)
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes ##dtypes tells us whether each column is an integer or a number, not ALWAYS accurate tho so be careful.
# Out:
# BENE_ID                          int64
# CLM_ID                           int64
# NCH_NEAR_LINE_REC_IDENT_CD      object
# NCH_CLM_TYPE_CD                  int64
# CLM_FROM_DT                     object
#                                 ...
# CLM_UNCOMPD_CARE_PMT_AMT       float64
# CLM_LINE_NUM                     int64
# REV_CNTR                         int64
# HCPCS_CD                        object
# REV_CNTR_DDCTBL_COINSRNC_CD    float64
# Length: 197, dtype: object

# %%
df['CLM_PMT_AMT'].describe()
# Out:
# count     58066.000000
# mean      13638.307734
# std       35993.907780
# min          62.440000
# 25%         945.370000
# 50%        1481.715000
# 75%        9932.040000
# max      598716.310000
# Name: CLM_PMT_AMT, dtype: float64

# %%
print(df.head())
# Out:
#           BENE_ID          CLM_ID NCH_NEAR_LINE_REC_IDENT_CD  NCH_CLM_TYPE_CD  \
# 0 -10000010254618 -10000930037831                          V               60
# 1 -10000010254653 -10000930038030                          V               60
# 2 -10000010254653 -10000930038031                          V               60
# 3 -10000010254656 -10000930038162                          V               60
# 4 -10000010254656 -10000930038162                          V               60
#
#    CLM_FROM_DT  CLM_THRU_DT NCH_WKLY_PROC_DT  FI_CLM_PROC_DT  \
# 0  25-Mar-2015  25-Mar-2015      27-Mar-2015             NaN
# 1  24-Sep-2015  24-Sep-2015      25-Sep-2015             NaN
# 2  09-May-2017  10-May-2017      12-May-2017             NaN
# 3  14-Jan-2017  14-Jan-2017      20-Jan-2017             NaN
# 4  14-Jan-2017  14-Jan-2017      20-Jan-2017             NaN
#
#    CLAIM_QUERY_CODE PRVDR_NUM  ...  PRCDR_DT24  ICD_PRCDR_CD25  PRCDR_DT25  \
# ...

# %%
codex_columns = [
    'PRNCPAL_DGNS_CD',
    'ICD_DGNS_CD1',
    'ICD_PRCDR_CD1',
    'CLM_DRG_CD',
    'ADMTG_DGNS_CD',
    'HCPCS_CD',
    'FST_DGNS_E_CD',
    'NCH_DRG_OUTLIER_APRVD_PMT_AMT'
]
for column in codex_columns:
    print(f"Frequency counts for {column}:")
    value_counts = df[column].value_counts()
    print(df[column].value_counts())
    print("\n")
# Out:
# Frequency counts for PRNCPAL_DGNS_CD:
# PRNCPAL_DGNS_CD
# Z733      11469
# Z608       7216
# T7432X     3314
# Z604       3227
# Z7682      3092
#           ...
# I25700        1
# I200          1
# E849          1
# A4152         1
# O00109        1
# Name: count, Length: 190, dtype: int64
#
#
# Frequency counts for ICD_DGNS_CD1:
# ICD_DGNS_CD1
# Z733      13031
# Z608       8227
# T7432X     3727
# Z604       3537
# Z940       2858
#           ...
# T8611         1
# E1141         1
# E11610        1
# I071          1
# M069          1
# Name: count, Length: 231, dtype: int64
#
#
# Frequency counts for ICD_PRCDR_CD1:
# ICD_PRCDR_CD1
# GZ3        16142
# Z741       12421
# BW03ZZZ     3337
# G4730       2134
# F13         2054
#            ...
# 3E03328        1
# 0HBU0ZX        1
# 02YA0Z2        1
# 0SRD0          1
# 0HCV3ZZ        1
# Name: count, Length: 114, dtype: int64
#
#
# Frequency counts for CLM_DRG_CD:
# CLM_DRG_CD
# 951.0    28831
# 950.0     1456
# 949.0     1332
# ...

# %%
codex_columns = [
    'PRNCPAL_DGNS_CD',
    'ICD_DGNS_CD1',
    'ICD_PRCDR_CD1',
    'CLM_DRG_CD',
    'ADMTG_DGNS_CD',
    'HCPCS_CD',
    'FST_DGNS_E_CD',
    'NCH_DRG_OUTLIER_APRVD_PMT_AMT'
]
for column in codex_columns:
    print(f"Missing counts for {column}:")
    value_counts = df[column].value_counts()
    print(df[column].value_counts())
    print("\n")
# Out:
# Missing counts for PRNCPAL_DGNS_CD:
# PRNCPAL_DGNS_CD
# Z733      11469
# Z608       7216
# T7432X     3314
# Z604       3227
# Z7682      3092
#           ...
# I25700        1
# I200          1
# E849          1
# A4152         1
# O00109        1
# Name: count, Length: 190, dtype: int64
#
#
# Missing counts for ICD_DGNS_CD1:
# ICD_DGNS_CD1
# Z733      13031
# Z608       8227
# T7432X     3727
# Z604       3537
# Z940       2858
#           ...
# T8611         1
# E1141         1
# E11610        1
# I071          1
# M069          1
# Name: count, Length: 231, dtype: int64
#
#
# Missing counts for ICD_PRCDR_CD1:
# ICD_PRCDR_CD1
# GZ3        16142
# Z741       12421
# BW03ZZZ     3337
# G4730       2134
# F13         2054
#            ...
# 3E03328        1
# 0HBU0ZX        1
# 02YA0Z2        1
# 0SRD0          1
# 0HCV3ZZ        1
# Name: count, Length: 114, dtype: int64
#
#
# Missing counts for CLM_DRG_CD:
# CLM_DRG_CD
# 951.0    28831
# 950.0     1456
# 949.0     1332
# ...

# %%
##STEP 2: Explore the Dataset
icd_codes = df['ICD_DGNS_CD1']
drg_codes = df['PRNCPAL_DGNS_CD']
hcpcs_codes = df['HCPCS_CD']

# %%
codex_columns = [
    'PRNCPAL_DGNS_CD',
    'ICD_DGNS_CD1',
    'ICD_PRCDR_CD1',
    'CLM_DRG_CD',
    'ADMTG_DGNS_CD',
    'HCPCS_CD',
    'FST_DGNS_E_CD',
    'NCH_DRG_OUTLIER_APRVD_PMT_AMT'
]
for column in codex_columns:
    print(f"Frequency counts for {column}:")
    value_counts = df[column].value_counts()
    print(df[column].value_counts())
    print("\n")
# Out:
# Frequency counts for PRNCPAL_DGNS_CD:
# PRNCPAL_DGNS_CD
# Z733      11469
# Z608       7216
# T7432X     3314
# Z604       3227
# Z7682      3092
#           ...
# I25700        1
# I200          1
# E849          1
# A4152         1
# O00109        1
# Name: count, Length: 190, dtype: int64
#
#
# Frequency counts for ICD_DGNS_CD1:
# ICD_DGNS_CD1
# Z733      13031
# Z608       8227
# T7432X     3727
# Z604       3537
# Z940       2858
#           ...
# T8611         1
# E1141         1
# E11610        1
# I071          1
# M069          1
# Name: count, Length: 231, dtype: int64
#
#
# Frequency counts for ICD_PRCDR_CD1:
# ICD_PRCDR_CD1
# GZ3        16142
# Z741       12421
# BW03ZZZ     3337
# G4730       2134
# F13         2054
#            ...
# 3E03328        1
# 0HBU0ZX        1
# 02YA0Z2        1
# 0SRD0          1
# 0HCV3ZZ        1
# Name: count, Length: 114, dtype: int64
#
#
# Frequency counts for CLM_DRG_CD:
# CLM_DRG_CD
# 951.0    28831
# 950.0     1456
# 949.0     1332
# ...

# %%
##STEP 3: Analyze the Frequency of Each Unique Value
icd_frequency = icd_codes.value_counts()
drg_frequency = drg_codes.value_counts()
hcpcs_frequency = hcpcs_codes.value_counts()

# %%
print("ICD Codes Frequency:\n", icd_frequency)
print("DRG Codes Frequency:\n", drg_frequency)
print("HCPCS Codes Frequency:\n", hcpcs_frequency)
# Out:
# ICD Codes Frequency:
#  ICD_DGNS_CD1
# Z733      13031
# Z608       8227
# T7432X     3727
# Z604       3537
# Z940       2858
#           ...
# T8611         1
# E1141         1
# E11610        1
# I071          1
# M069          1
# Name: count, Length: 231, dtype: int64
# DRG Codes Frequency:
#  PRNCPAL_DGNS_CD
# Z733      11469
# Z608       7216
# T7432X     3314
# Z604       3227
# Z7682      3092
#           ...
# I25700        1
# I200          1
# E849          1
# A4152         1
# O00109        1
# Name: count, Length: 190, dtype: int64
# HCPCS Codes Frequency:
#  HCPCS_CD
# 99221    8298
# G0444    7990
# 96156    5080
# 99408    4196
# 99495    3867
#          ...
# S9361       1
# S9355       1
# S9374       1
# S9377       1
# G9829       1
# Name: count, Length: 106, dtype: int64

# %%
codex_columns = [
    'PRNCPAL_DGNS_CD',
    'ICD_DGNS_CD1',
    'ICD_PRCDR_CD1',
    'CLM_DRG_CD',
    'ADMTG_DGNS_CD',
    'HCPCS_CD',
    'FST_DGNS_E_CD',
    'NCH_DRG_OUTLIER_APRVD_PMT_AMT'
]
for column in codex_columns:
    print(f"Missing counts for {column}:")
    value_counts = df[column].value_counts()
    print(df[column].value_counts())
    print("\n")
# Out:
# Missing counts for PRNCPAL_DGNS_CD:
# PRNCPAL_DGNS_CD
# Z733      11469
# Z608       7216
# T7432X     3314
# Z604       3227
# Z7682      3092
#           ...
# I25700        1
# I200          1
# E849          1
# A4152         1
# O00109        1
# Name: count, Length: 190, dtype: int64
#
#
# Missing counts for ICD_DGNS_CD1:
# ICD_DGNS_CD1
# Z733      13031
# Z608       8227
# T7432X     3727
# Z604       3537
# Z940       2858
#           ...
# T8611         1
# E1141         1
# E11610        1
# I071          1
# M069          1
# Name: count, Length: 231, dtype: int64
#
#
# Missing counts for ICD_PRCDR_CD1:
# ICD_PRCDR_CD1
# GZ3        16142
# Z741       12421
# BW03ZZZ     3337
# G4730       2134
# F13         2054
#            ...
# 3E03328        1
# 0HBU0ZX        1
# 02YA0Z2        1
# 0SRD0          1
# 0HCV3ZZ        1
# Name: count, Length: 114, dtype: int64
#
#
# Missing counts for CLM_DRG_CD:
# CLM_DRG_CD
# 951.0    28831
# 950.0     1456
# 949.0     1332
# ...

# %%
## STEP 4: HANDLING MISSING DATA
missing_icd = icd_codes.isnull().sum()
missing_drg = drg_codes.isnull().sum()
missing_hcpcs = hcpcs_codes.isnull().sum()

# %%
print(f"Missing ICD Codes: {missing_icd}")
print(f"Missing DRG Codes: {missing_drg}")
print(f"Missing HCPCS Codes: {missing_hcpcs}")
# Out:
# Missing ICD Codes: 0
# Missing DRG Codes: 0
# Missing HCPCS Codes: 0

# %%
df['ICD_DGNS_CD1'].fillna('MISSING', inplace=True)
df['PRNCPAL_DGNS_CD'].fillna('MISSING', inplace=True)
df['HCPCS_CD'].fillna('MISSING', inplace=True)

# %%
## STEP 5: Summary of Findings
print("Top 5 Most Common ICD Codes:\n", icd_frequency.head())
print("Top 5 Most Common DRG Codes:\n", drg_frequency.head())
print("Top 5 Most Common HCPCS Codes:\n", hcpcs_frequency.head())
# Out:
# Top 5 Most Common ICD Codes:
#  ICD_DGNS_CD1
# Z733      13031
# Z608       8227
# T7432X     3727
# Z604       3537
# Z940       2858
# Name: count, dtype: int64
# Top 5 Most Common DRG Codes:
#  PRNCPAL_DGNS_CD
# Z733      11469
# Z608       7216
# T7432X     3314
# Z604       3227
# Z7682      3092
# Name: count, dtype: int64
# Top 5 Most Common HCPCS Codes:
#  HCPCS_CD
# 99221    8298
# G0444    7990
# 96156    5080
# 99408    4196
# 99495    3867
# Name: count, dtype: int64

# %%
##Additional Analysis Example
diabetes_related = df[df['ICD_DGNS_CD1'].str.contains('E11', na=False)]
common_drg_for_diabetes = diabetes_related['PRNCPAL_DGNS_CD'].value_counts()
print("Most Common DRG Codes for Patients with ICD Code E11 (Type 2 Diabetes):\n", common_drg_for_diabetes)
# Out:
# Most Common DRG Codes for Patients with ICD Code E11 (Type 2 Diabetes):
#  PRNCPAL_DGNS_CD
# E1122      54
# T50901A    15
# E113519     6
# E119        6
# I0981       3
# I509        2
# J45909      2
# E113299     2
# Z3480       1
# M797        1
# Name: count, dtype: int64
